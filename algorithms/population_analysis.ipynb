# %%
import pandas as pd

# %%
url = "https://dlai-lc-dag.s3.us-east-2.amazonaws.com/countries_and_pet_population.html"

# %%
tables = pd.read_html(url)

# %%
type(tables)
# Out:
# list

# %%
len(tables)
# Out:
# 1

# %%
type(tables[0])
# Out:
# pandas.core.frame.DataFrame

# %%
tables[0].head()
# Out:
#          Country  Population 2022  Population 2023 Change %            Region  \
# 0          World       8021407192       8091734930   +0.88%      WRLD - World
# 1          India       1425423212       1438069596   +0.89%      ASIA - South
# 2      China [a]       1425179569       1422584933   -0.18%       ASIA - East
# 3  United States        341534046        343477335   +0.57%      AMER - North
# 4      Indonesia        278830529        281190067   +0.85%  ASIA - Southeast
#
#   Official Language  Dog Population  Cat Population  Bird Population  \
# 0               NaN             NaN             NaN              NaN
# 1    Hindi, English      10200000.0             NaN              NaN
# 2  Standard Chinese      27400000.0      53100000.0              NaN
# 3           English      69929000.0      74059000.0        8300000.0
# 4        Indonesian             NaN             NaN              NaN
#
#    Aquaria Population  Small Mammal Population  Terraria Population
# ...

# %%
df = tables[0]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  238 non-null    object
#  1   Population 2022          238 non-null    int64
#  2   Population 2023          238 non-null    int64
#  3   Change %                 238 non-null    object
#  4   Region                   238 non-null    object
#  5   Official Language        191 non-null    object
#  6   Dog Population           38 non-null     float64
#  7   Cat Population           35 non-null     float64
#  8   Bird Population          32 non-null     float64
#  9   Aquaria Population       29 non-null     float64
#  10  Small Mammal Population  29 non-null     float64
#  11  Terraria Population      27 non-null     float64
# dtypes: float64(6), int64(2), object(4)
# memory usage: 22.4+ KB

# %%
38/238
# Out:
# 0.15966386554621848

# %%
#average growth rate
df["Change %"].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 #average growth rate
# ----> 2 df["Change %"].mean()
#
# File c:\Users\megha\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:6560, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6552 @doc(make_doc("mean", ndim=1))
#    6553 def mean(
#    6554     self,
#    (...)
#    6558     **kwargs,
#    6559 ):
# -> 6560     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\megha\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:12439, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12432 def mean(
#   12433     self,
#   12434     axis: Axis | None = 0,
#    (...)
#   12437     **kwargs,
#   12438 ) -> Series | float:
# > 12439     return self._stat_function(
# ...

# %% [markdown]
# ## Replace

# %%
#using replace() method
countries = "India, China, United States, Indonesia"
countries.replace("United States", "USA")
# Out:
# 'India, China, USA, Indonesia'

# %%
"+0.88%".replace("%","")
# Out:
# '+0.88'

# %%
df["Change %"] = df["Change %"].replace("%","")

# %%
df['Change %'].head()
# Out:
# 0    +0.88%
# 1    +0.89%
# 2    -0.18%
# 3    +0.57%
# 4    +0.85%
# Name: Change %, dtype: object

# %%
df["Change %"] = df["Change %"].str.replace("%","")
df['Change %'].head()
# Out:
# 0    +0.88
# 1    +0.89
# 2    -0.18
# 3    +0.57
# 4    +0.85
# Name: Change %, dtype: object

# %% [markdown]
# ## Casting
#
# casting a column in a pandas dataframe to another type using this method appropriately handles the missing values.

# %%
df['Change %'] = df['Change %'].astype("float64") # float64 will handle mising values

# %%
df['Change %'].head()
# Out:
# 0    0.88
# 1    0.89
# 2   -0.18
# 3    0.57
# 4    0.85
# Name: Change %, dtype: float64

# %%
df['Change %'].mean()
# Out:
# np.float64(1.0084873949579831)

# %%
df.dtypes
# Out:
# Country                     object
# Population 2022              int64
# Population 2023              int64
# Change %                   float64
# Region                      object
# Official Language           object
# Dog Population             float64
# Cat Population             float64
# Bird Population            float64
# Aquaria Population         float64
# Small Mammal Population    float64
# Terraria Population        float64
# dtype: object

# %% [markdown]
# ### Handling missing data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  238 non-null    object
#  1   Population 2022          238 non-null    int64
#  2   Population 2023          238 non-null    int64
#  3   Change %                 238 non-null    float64
#  4   Region                   238 non-null    object
#  5   Official Language        191 non-null    object
#  6   Dog Population           38 non-null     float64
#  7   Cat Population           35 non-null     float64
#  8   Bird Population          32 non-null     float64
#  9   Aquaria Population       29 non-null     float64
#  10  Small Mammal Population  29 non-null     float64
#  11  Terraria Population      27 non-null     float64
# dtypes: float64(7), int64(2), object(3)
# memory usage: 22.4+ KB

# %%
df_with_dogs = df.dropna(subset = ["Dog Population"])

# %%
df_with_dogs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38 entries, 1 to 157
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  38 non-null     object
#  1   Population 2022          38 non-null     int64
#  2   Population 2023          38 non-null     int64
#  3   Change %                 38 non-null     float64
#  4   Region                   38 non-null     object
#  5   Official Language        38 non-null     object
#  6   Dog Population           38 non-null     float64
#  7   Cat Population           35 non-null     float64
#  8   Bird Population          31 non-null     float64
#  9   Aquaria Population       29 non-null     float64
#  10  Small Mammal Population  29 non-null     float64
#  11  Terraria Population      27 non-null     float64
# dtypes: float64(7), int64(2), object(3)
# memory usage: 3.9+ KB

# %%
#fill in missing values with reasonable guess - mean dogs per capita
df["dogs_per_capita"] = df["Dog Population"]/df["Population 2023"]

# %%
df["dogs_per_capita"].describe()
# Out:
# count    38.000000
# mean      0.137065
# std       0.069887
# min       0.007093
# 25%       0.099721
# 50%       0.128252
# 75%       0.183206
# max       0.297817
# Name: dogs_per_capita, dtype: float64

# %%
df["Dog Population"] = df["Dog Population"].fillna(df["Population 2023"] * 0.137065)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  238 non-null    object
#  1   Population 2022          238 non-null    int64
#  2   Population 2023          238 non-null    int64
#  3   Change %                 238 non-null    float64
#  4   Region                   238 non-null    object
#  5   Official Language        191 non-null    object
#  6   Dog Population           238 non-null    float64
#  7   Cat Population           35 non-null     float64
#  8   Bird Population          32 non-null     float64
#  9   Aquaria Population       29 non-null     float64
#  10  Small Mammal Population  29 non-null     float64
#  11  Terraria Population      27 non-null     float64
#  12  dogs_per_capita          38 non-null     float64
# dtypes: float64(8), int64(2), object(3)
# ...

# %%
df["Dog Population"].describe()
# Out:
# count    2.380000e+02
# mean     7.825225e+06
# std      7.203852e+07
# min      6.798424e+01
# 25%      5.514899e+04
# 50%      7.384561e+05
# 75%      3.185980e+06
# max      1.109094e+09
# Name: Dog Population, dtype: float64

# %% [markdown]
# ### String Method: contains()

# %%
# create the column english which contains true if for one of the countries it is found as officlal language
df["English"] = df["Official Language"] == "English"

# %%
df["English"].head()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# Name: English, dtype: bool

# %%
#we need find a way not just equal but somewhere in the string
df["English"] = df["Official Language"].str.contains("English")

# %%
df["English"].head()
# Out:
# 0      NaN
# 1     True
# 2    False
# 3     True
# 4    False
# Name: English, dtype: object

# %%
english_df = df[df["English"] == True]

# %%
len(english_df)
# Out:
# 56

# %%
#summing the population of all these countries
english_df["Population 2023"].sum()
# Out:
# np.int64(3010448677)

# %% [markdown]
# there are 3 million people living in english speaking countries.

# %%
#case sensitive
df["English"] = df["Official Language"].str.contains("English", case = False)

# %%
df["English"].sum()
# Out:
# 56

# %%
df["German"] = df["Official Language"].str.contains("German", case = False)

# %%
df["German"].sum()
# Out:
# 6

# %% [markdown]
# ### String method: split and strip

# %%
df.head()
# Out:
#          Country  Population 2022  Population 2023  Change %  \
# 0          World       8021407192       8091734930      0.88
# 1          India       1425423212       1438069596      0.89
# 2      China [a]       1425179569       1422584933     -0.18
# 3  United States        341534046        343477335      0.57
# 4      Indonesia        278830529        281190067      0.85
#
#              Region Official Language  Dog Population  Cat Population  \
# 0      WRLD - World               NaN    1.109094e+09             NaN
# 1      ASIA - South    Hindi, English    1.020000e+07             NaN
# 2       ASIA - East  Standard Chinese    2.740000e+07      53100000.0
# 3      AMER - North           English    6.992900e+07      74059000.0
# 4  ASIA - Southeast        Indonesian    3.854132e+07             NaN
#
#    Bird Population  Aquaria Population  Small Mammal Population  \
# 0              NaN                 NaN                      NaN
# ...

# %%
text = "China [a]"
substrings = text.split("[")
substrings
# Out:
# ['China ', 'a]']

# %%
len(substrings)
# Out:
# 2

# %%
substrings[0]
# Out:
# 'China '

# %%
df["Country"]
# Out:
# 0                                  World
# 1                                  India
# 2                              China [a]
# 3                          United States
# 4                              Indonesia
#                      ...
# 233          Montserrat (United Kingdom)
# 234    Falkland Islands (United Kingdom)
# 235                Tokelau (New Zealand)
# 236                   Niue (New Zealand)
# 237                     Vatican City [x]
# Name: Country, Length: 238, dtype: object

# %%
df["Country"].str.split("[")
# Out:
# 0                                  [World]
# 1                                  [India]
# 2                             [China , a]]
# 3                          [United States]
# 4                              [Indonesia]
#                       ...
# 233          [Montserrat (United Kingdom)]
# 234    [Falkland Islands (United Kingdom)]
# 235                [Tokelau (New Zealand)]
# 236                   [Niue (New Zealand)]
# 237                    [Vatican City , x]]
# Name: Country, Length: 238, dtype: object

# %%
df['Country'] = df['Country'].str.split("[").str[0]

# %%
df['Country'].str.contains("]").sum()
# Out:
# np.int64(0)

# %%
df["Country"].head()
# Out:
# 0            World
# 1            India
# 2           China
# 3    United States
# 4        Indonesia
# Name: Country, dtype: object

# %%
df['Country'] = df['Country'].str.strip()

# %%
df['Country'].head()
# Out:
# 0            World
# 1            India
# 2            China
# 3    United States
# 4        Indonesia
# Name: Country, dtype: object

# %% [markdown]
# Now let's see which country love more cats than dogs

# %%
# Find the number of dogs per capita (as seen in demos)
df["dogs_per_capita"] = df["Dog Population"] / df["Population 2023"]

# Find the mean number of dogs per capita
mean_dogs_per_capita = df["dogs_per_capita"].mean()

df["Dog Population"] = df["Dog Population"].fillna(df["Population 2023"] * mean_dogs_per_capita)

### START CODE HERE ###

# Find the number of cats per capita (as seen in demos)
df["cats_per_capita"] = df['Cat Population'] /df['Population 2023']

# Find the mean number of dogs per capita
mean_cats_per_capita = df["cats_per_capita"].mean()

df["Cat Population"] = df["Cat Population"].fillna(df["Population 2023"]* mean_cats_per_capita)

# Create a new column 'Cats > Dogs' that contains True if the number of cats is greater than the number of dogs and False otherwise
df["Cats > Dogs"] = df["Cat Population"] > df["Dog Population"]

### END CODE HERE ###

# Display the first few rows of the new dataframe
df.head()
# Out:
#          Country  Population 2022  Population 2023  Change %  \
# 0          World       8021407192       8091734930      0.88
# 1          India       1425423212       1438069596      0.89
# 2          China       1425179569       1422584933     -0.18
# 3  United States        341534046        343477335      0.57
# 4      Indonesia        278830529        281190067      0.85
#
#              Region Official Language  Dog Population  Cat Population  \
# 0      WRLD - World               NaN    1.109094e+09    1.240733e+09
# 1      ASIA - South    Hindi, English    1.020000e+07    2.205041e+08
# 2       ASIA - East  Standard Chinese    2.740000e+07    5.310000e+07
# 3      AMER - North           English    6.992900e+07    7.405900e+07
# 4  ASIA - Southeast        Indonesian    3.854132e+07    4.311583e+07
#
#    Bird Population  Aquaria Population  Small Mammal Population  \
# 0              NaN                 NaN                      NaN
# ...

# %%
### START CODE HERE ###

# Clean the 'Region' column to remove citations
df["Region"] = df['Region'].str.split("-").str[0]

# Remove leading and trailing whitespaces from the 'Region' column
df["Region"] = df['Region'].str.strip()

### END CODE HERE ###

# Find the number of cats and dogs per continent
df.groupby("Region")[["Dog Population", "Cat Population"]].sum()
# Out:
#         Dog Population  Cat Population
# Region
# AFRC      1.890585e+08    2.193590e+08
# AMER      1.686021e+08    1.771517e+08
# ASIA      2.805488e+08    5.470651e+08
# EURP      1.087809e+08    1.294804e+08
# OCNA      6.319540e+06    5.130456e+06
# WRLD      1.109094e+09    1.240733e+09

# %%
import plotly.express as px

# Clean the 'Country' column to remove citations
df["Country"] = df["Country"].str.split("[").str[0]

# Remove leading and trailing whitespaces from the 'Country' column
df["Country"] = df["Country"].str.strip()

### START CODE HERE ###
# Use this block to create the plot
color_map = {True:'Green',False:'Red'}
fig = px.choropleth(df,
                   locations = "Country",
                   locationmode = "country names",
                   color = "Cats > Dogs",
                   color_discrete_map = color_map,
                   title = "Countries with more Cats than Dogs")
fig.show()
### END CODE HERE ###
# Out:
# C:\Users\megha\AppData\Local\Temp\ipykernel_15980\2187970589.py:12: DeprecationWarning: The library used by the *country names* `locationmode` option is changing in an upcoming version. Country names in existing plots may not work in the new version. To ensure consistent behavior, consider setting `locationmode` to *ISO-3*.
#   fig = px.choropleth(df,
